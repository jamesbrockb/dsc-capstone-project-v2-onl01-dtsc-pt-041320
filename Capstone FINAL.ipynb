# %% [markdown]
# # Capstone

# %% [markdown]
# ## Introduction
#
# The goal in the notebook below is to understand / find out what it takes, lyrically, to be in the Billboard Top 100 Charts. The data explored is largely from the years between 1999-2019, however there is some additional data that dates back to 1959.
#
# Throughout the notebook, we will be extensively cleaning our data (15k+ data entries to 4k+) and performing three separate models. The models being ran throughout the notebook are Random Forests, XGB and SVM. Additionally there will be further data exploration on how genre can play an intricate role when it comes to being involved in the Billboard's top 100 chart.

# %% [markdown]
# The following variable was created as to not run cell 7. Cell 7 is where I scraped for both a genius API and a spotify API to get lyrics as well as certain spotify features. If you'd like to run cell 7 to see how it works, please feel free to change False to True.

# %%
scrape = False
api_file = '/Users/jamesbrochhausen/.secret/Spotify.json'

# %%
import pandas as pd
import numpy as np
import pandas as pd
import sklearn.metrics as metrics
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import plot_confusion_matrix, recall_score
from xgboost import XGBRFClassifier,XGBClassifier
import shap
from imblearn.over_sampling import SMOTE
shap.initjs()
import warnings
from collections import Counter
from nltk import FreqDist
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
import string
from wordcloud import WordCloud
warnings.filterwarnings('ignore')
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Using TensorFlow backend.
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Loading in our first data set

# %% [markdown]
# The below data set is going to be used control variable for songs that did not exist in our Billboard top 100 list we will be working with later.

# %%
## Loading in data
df_rando = pd.read_csv('Spotify-2000.csv', index_col=[0])

df_rando.head()
# Out:
#                         Title             Artist            Top Genre  Year  \
# Index
# 1                     Sunrise        Norah Jones      adult standards  2004
# 2                 Black Night        Deep Purple           album rock  2000
# 3              Clint Eastwood           Gorillaz  alternative hip hop  2001
# 4               The Pretender       Foo Fighters    alternative metal  2007
# 5      Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002
#
#        Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# Index
# 1                         157      30            53            -14        11
# 2                         135      79            50            -11        17
# 3                         168      69            66             -9         7
# 4                         173      96            43             -4         3
# 5                         106      82            58             -5        10
#
#        Valence Length (Duration)  Acousticness  Speechiness  Popularity
# Index
# 1           68               201            94            3          71
# 2           81               207            17            7          39
# 3           52               341             2           17          69
# 4           37               269             0            4          76
# 5           87               256             1            3          59

# %% [markdown]
# ### Spotify and Genius API
# Next is to scrape additional data for our above data set as we need lyrics. We'll do this by leveraging the Genius API. I was planning on leveraging the Spotify API call to gather additional information later on in regards other features such as BPM, Valence, Tempo etc. However given timing constraints I was not able to further explore how these played a roll in our goal.

# %%
import os

# %%
# pip install lyricsgenius
# pip install spotipy

# %%
if scrape:
    import json

    with open(api_file) as file:
        login = json.loads(file.read())

    login.keys()

    import spotipy
    from spotipy.oauth2 import SpotifyClientCredentials

    sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=login['client_id'],
                                                               client_secret=login['client_secret']))

    df_rando['Lyrics']=''
    df_rando.head()

    import lyricsgenius
    genius = lyricsgenius.Genius(login['genius_secret'])

    def get_lyrics(x):
        title = x['Title']
        artist = x['Artist']

        song = genius.search_song(title, artist)
    #     print(song.lyrics)
        try: 
            return song.lyrics
        except:
            return 'Not Found'
    print('Scraping data')
    df_rando['Lyrics']=df_rando.apply(lambda x: get_lyrics(x), axis=1)

    df_rando.to_csv('randomsongs.csv',index=False)
else:
     print ('Skipping since scrape == False')   
# Change this to a relative file path
# Out:
# Skipping since scrape == False

# %%
df_rando = pd.read_csv('randomsongs.csv')
df_rando.head()
# Out:
#                     Title             Artist            Top Genre  Year  \
# 0                 Sunrise        Norah Jones      adult standards  2004
# 1             Black Night        Deep Purple           album rock  2000
# 2          Clint Eastwood           Gorillaz  alternative hip hop  2001
# 3           The Pretender       Foo Fighters    alternative metal  2007
# 4  Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002
#
#    Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# 0                     157      30            53            -14        11
# 1                     135      79            50            -11        17
# 2                     168      69            66             -9         7
# 3                     173      96            43             -4         3
# 4                     106      82            58             -5        10
#
#    Valence Length (Duration)  Acousticness  Speechiness  Popularity  \
# 0       68               201            94            3          71
# 1       81               207            17            7          39
# 2       52               341             2           17          69
# 3       37               269             0            4          76
# 4       87               256             1            3          59
#
#                                               Lyrics
# 0  [Verse 1]\nSunrise, sunrise\nLooks like mornin...
# 1  [Verse 1]\nBlack night is not right\nI don't f...
# 2  [Intro: 2D]\nHoo-hoo-hoo-hoo-hoo\n\n[Chorus: 2...
# 3  [Intro]\nKeep you in the dark\nYou know they a...
# 4  [Verse 1]\nIt's raining, but there ain't a clo...

# %% [markdown]
# I need to make sure all of our lyrics are here before proceeding. After cross referencing online with other lyrical websites, I can confirm all the appropriate lyrics were pulled into our data set.

# %%
print(df_rando['Lyrics'].iloc[0])
# Out:
# [Verse 1]
# Sunrise, sunrise
# Looks like mornin' in your eyes
# But the clock's held 9:15 for hours
# Sunrise, sunrise
# Couldn't tempt us if it tried
# 'Cause the afternoon's already come and gone
#
# [Chorus 1]
# And I said
# Hoo-ooh-ooh-ooh
# Hoo-ooh-ooh-ooh
# Hoo-ooh-ooh-ooh
# To you
#
# [Verse 2]
# Surprise, surprise
# Couldn't find it in your eyes
# But I'm sure it's written all over my face
# Surprise, surprise
# Never something I could hide
# When I see we made it through another day
#
# [Chorus 1]
# And I said
# Hoo-ooh-ooh-ooh
# Hoo-ooh-ooh-ooh
# Hoo-ooh-ooh-ooh
# To you
#
# [Bridge]
# Now the night
# Will throw its cover down
# On me again
# Ooh, and if I'm right
# It's the only way
# To bring me back
#
# [Chorus 2]
# Hoo-ooh-ooh-ooh
# Hoo-ooh-ooh-ooh
# Hoo-ooh-ooh-ooh
# To you
# Hoo-ooh-yeah
# Hoo-ooh-ooh-ooh
# Hoo-ooh-ooh-ooh
# To you

# %% [markdown]
# Now that I've confirmed all the lyrics are in the songs, I need to go through the Lyrics column and removes words like Chorus and Bridge and Verse. The main reason being that these words are not important to what we're trying to solve for as these are merely transitions and not part of the lyrics.

# %%
## Removing words from rows in Lyrics Column

word_list = ['[Chorus 1]','[Chorus 2]','[Chorus 3]','[Chorus 4]',
             '[Verse 1]','[Verse 2]','[Verse 3]','[Verse 4]','[Bridge]',
             '[Intro]','[Chorus]','[Outro]','[outro]','[Verse]','[verse]',
            '[Pre-Chorus]','[pre-chorus]','[Instrumental]','[instrumental]',
             '[post-chorus]','[Post-Chorus]']

# %%
def replace_words(word_list, lyrics):
#     print(lyrics)
    for word in word_list:
        if word in lyrics:
            lyrics = lyrics.replace(word,'')
#             print(word)
    return lyrics


df_rando['Lyrics']=df_rando['Lyrics'].apply(lambda x: replace_words(word_list,
                                                                    x))

# %%
print(df_rando['Lyrics'][1])
# Out:
# Black night is not right
# I don't feel so bright
# I don't care to sit tight
#
#
# Maybe I'll find on the way down the line
# That I'm free, free to be me
# Black night is a long way from home
#
#
# I don't need a dark tree
# I don't want a rough sea
# I can't feel, I can't see
#
#
# Maybe I'll find on the way down the line
# That I'm free, free to be me
# Black night is a long way from home
#
#
# Black night, black night
# I don't need black night
# I can't see dark light
#
#
# Maybe I'll find on the way down the line
# That I'm free, free to be me
# Black night is a long way from home

# %% [markdown]
# ## Loading in our second data set

# %% [markdown]
# Now we're loading in our dataset that contains all the songs from 1999-2019 that have been in the billboards top 100.

# %%
## Loading in the data
df_bb = pd.read_csv('billboardHot100_1999-2019.csv.zip', index_col=[0])

# %% [markdown]
# Removing unnecessary columns for our solution.

# %%
df_bb = df_bb.drop(columns=['Features','Writing.Credits','Week','Date'])
df_bb.head()
# Out:
#                         Artists           Name  Weekly.rank  Peak.position  \
# 1                      Lil Nas,  Old Town Road            1            1.0
# 2  Shawn Mendes, Camila Cabello       Senorita            2            NaN
# 3                 Billie Eilish        Bad Guy            3            2.0
# 4                        Khalid           Talk            4            3.0
# 5     Ed Sheeran, Justin Bieber   I Don't Care            5            2.0
#
#    Weeks.on.chart                                              Genre  \
# 1             7.0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 2             NaN                                                Pop
# 3            13.0  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 4            20.0                                      Synth-Pop,Pop
# 5             7.0                      Canada,UK,Dance,Dance-Pop,Pop
#
#                                               Lyrics
# 1  Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...
# 2  Senorita \nI love it when you call me senorita...
# 3  bad guy \nWhite shirt now red, my bloody nose\...
# 4  Talk \nCan we just talk? Can we just talk?\nTa...
# 5  I Don't Care \nI'm at a party I don't wanna be...

# %% [markdown]
# Once again we're confirming that all of the lyrics are in the songs.

# %%
print(df_bb['Lyrics'].iloc[0])
# Out:
# Old Town Road Remix
# Oh, oh-oh
# Oh
# Yeah, I'm gonna take my horse to the old town road
# I'm gonna ride til I can't no more
# I'm gonna take my horse to the old town road
# I'm gonna ride til I can't no more
# Kio, Kio
# I got the horses in the back
# Horse tack is attached
# Hat is matte black
# Got the boots that's black to match
# Riding on a horse, ha
# You can whip your Porsche
# I been in the valley
# You ain't been up off that porch, now
# Can't nobody tell me nothin'
# You can't tell me nothin'
# Can't nobody tell me nothin'
# You can't tell me nothin'
# Riding on a tractor
# Lean all in my bladder
# Cheated on my baby
# You can go and ask her
# My life is a movie
# Bull riding and boobies
# Cowboy hat from Gucci
# Wrangler on my booty
# Can't nobody tell me nothin'
# You can't tell me nothin'
# Can't nobody tell me nothin'
# You can't tell me nothin'
# Yeah, I'm gonna take my horse to the old town road
# I'm gonna ride til I can't no more
# I'm gonna take my horse to the old town road
# I'm gonna ride til I can't no more
# Hat down, cross town, living like a rockstar
# Spent a lot of money on my brand new guitar
# Baby's got a habit: diamond rings and Fendi sports bras
# Riding down Rodeo in my Maserati sports car
# Got no stress, I've been through all that
# I'm like a Marlboro Man so I kick on back
# Wish I could roll on back to that old town road
# I wanna ride til I can't no more
# Yeah, I'm gonna take my horse to the old town road
# I'm gonna ride til I can't no more
# I'm gonna take my horse to the old town road
# I'm gonna ride til I can't no more

# %%
df_bb.shape
# Out:
# (97225, 7)

# %%
## Checking for duplicates
df_bb['Name'].duplicated().any()
# Out:
# True

# %% [markdown]
# Since I'm going to eventually be joining this column with my Hot Stuff (loaded further below) column below, I'm going to need to remove any and all duplicates before I can initiate that process down the line.

# %%
df_bb['Name'].duplicated().value_counts()
# Out:
# True     90767
# False     6458
# Name: Name, dtype: int64

# %% [markdown]
# The dataset above houses duplicate songs as they appear multiple times in a week and multiple times throughout a year. Which makes sense why there are so many. What we care about most however is the lyrics and how similar they are to one another. So we're going to drop all duplicate lyrics (just in case there are some songs with the same title).

# %%
df_bb['Lyrics'].duplicated().value_counts()
# Out:
# True     90020
# False     7205
# Name: Lyrics, dtype: int64

# %%
df_bb[df_bb['Lyrics'].duplicated(keep=False)].sort_values('Lyrics')
# Out:
#              Artists                          Name  Weekly.rank  \
# 80318            Jay            '03 Bonnie & Clyde            6
# 80785            Jay            '03 Bonnie & Clyde            4
# 81164            Jay            '03 Bonnie & Clyde           11
# 80692            Jay            '03 Bonnie & Clyde            4
# 79598            Jay            '03 Bonnie & Clyde           46
# ...              ...                           ...          ...
# 683    Billie Eilish  You Should See Me In A Crown           92
# 1051   Billie Eilish  You Should See Me In A Crown           65
# 4781   Billie Eilish  You Should See Me In A Crown           93
# 869    Billie Eilish  You Should See Me In A Crown           80
# 1152   Billie Eilish  You Should See Me In A Crown           68
#
#        Peak.position  Weeks.on.chart  \
# 80318            4.0            15.0
# 80785            4.0            10.0
# 81164           11.0             6.0
# 80692            4.0            11.0
# 79598            4.0            23.0
# ...              ...             ...
# 683             41.0             8.0
# 1051            41.0             4.0
# 4781             NaN             NaN
# 869             41.0             6.0
# 1152            41.0             3.0
#
#                                                    Genre  \
# 80318                                West Coast,R&;B,Rap
# 80785                                West Coast,R&;B,Rap
# 81164                                West Coast,R&;B,Rap
# 80692                                West Coast,R&;B,Rap
# 79598                                West Coast,R&;B,Rap
# ...                                                  ...
# 683    Indie,Hip-Hop,Dark Pop,Alternative Pop,Alterna...
# 1051   Indie,Hip-Hop,Dark Pop,Alternative Pop,Alterna...
# 4781   Indie,Hip-Hop,Dark Pop,Alternative Pop,Alterna...
# 869    Indie,Hip-Hop,Dark Pop,Alternative Pop,Alterna...
# 1152   Indie,Hip-Hop,Dark Pop,Alternative Pop,Alterna...
#
#                                                   Lyrics
# 80318  '03 Bonnie & Clyde \nUhh, uhh, uhh\nYou ready,...
# 80785  '03 Bonnie & Clyde \nUhh, uhh, uhh\nYou ready,...
# 81164  '03 Bonnie & Clyde \nUhh, uhh, uhh\nYou ready,...
# 80692  '03 Bonnie & Clyde \nUhh, uhh, uhh\nYou ready,...
# 79598  '03 Bonnie & Clyde \nUhh, uhh, uhh\nYou ready,...
# ...                                                  ...
# 683    you should see me in a crown \nBite my tongue,...
# 1051   you should see me in a crown \nBite my tongue,...
# 4781   you should see me in a crown \nBite my tongue,...
# 869    you should see me in a crown \nBite my tongue,...
# 1152   you should see me in a crown \nBite my tongue,...
#
# [95953 rows x 7 columns]

# %%
df_bb = df_bb.drop_duplicates(subset=['Lyrics'])

print(df_bb.shape)
df_bb.head(3)
# Out:
# (7205, 7)
#                         Artists           Name  Weekly.rank  Peak.position  \
# 1                      Lil Nas,  Old Town Road            1            1.0
# 2  Shawn Mendes, Camila Cabello       Senorita            2            NaN
# 3                 Billie Eilish        Bad Guy            3            2.0
#
#    Weeks.on.chart                                              Genre  \
# 1             7.0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 2             NaN                                                Pop
# 3            13.0  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
#
#                                               Lyrics
# 1  Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...
# 2  Senorita \nI love it when you call me senorita...
# 3  bad guy \nWhite shirt now red, my bloody nose\...

# %% [markdown]
# ## Loading in our final data set

# %% [markdown]
# This data set was loaded to help pair with our df_bb data set when it came to the spotify features. Once those two data sets are combined we'll finally combine our initial data set (the control data set).

# %%
df_hot_audio_features = pd.read_csv('Hot 100 Audio Features.csv')
df_hot_audio_features.head(3)
# Out:
#                                               SongID  \
# 0                      AdictoTainy, Anuel AA & Ozuna
# 1  The Ones That Didn't Make It Back HomeJustin M...
# 2                  ShallowLady Gaga & Bradley Cooper
#
#                     Performer                                    Song  \
# 0     Tainy, Anuel AA & Ozuna                                  Adicto
# 1                Justin Moore  The Ones That Didn't Make It Back Home
# 2  Lady Gaga & Bradley Cooper                                 Shallow
#
#                                        spotify_genre        spotify_track_id  \
# 0                                  ['pop reggaeton']  3jbT1Y5MoPwEIpZndDDwVq
# 1  ['arkansas country', 'contemporary country', '...                     NaN
# 2                               ['dance pop', 'pop']  2VxeLyX666F8uXCJ0dZF8B
#
#   spotify_track_preview_url             spotify_track_album  \
# 0                       NaN  Adicto (with Anuel AA & Ozuna)
# 1                       NaN                             NaN
# 2                       NaN       A Star Is Born Soundtrack
#
#   spotify_track_explicit  spotify_track_duration_ms  spotify_track_popularity  \
# 0                  False                   270740.0                      91.0
# 1                    NaN                        NaN                       NaN
# 2                  False                   215733.0                      88.0
#
#    ...   key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  ...  10.0    -4.803   0.0       0.0735         0.017          0.000016
# 1  ...   NaN       NaN   NaN          NaN           NaN               NaN
# 2  ...   7.0    -6.362   1.0       0.0308         0.371          0.000000
#
#    liveness  valence   tempo  time_signature
# 0     0.179    0.623  80.002             4.0
# 1       NaN      NaN     NaN             NaN
# 2     0.231    0.323  95.799             4.0
#
# [3 rows x 22 columns]

# %%
##Further removing features I don't want included

df_hot_audio_features = df_hot_audio_features.drop(columns=['spotify_track_id',
                                    'spotify_track_preview_url',
                     'spotify_track_album','spotify_track_explicit',
                     'spotify_track_duration_ms'])

# %% [markdown]
# Checking duplicates again to remove before joining our two data frames.

# %%
df_hot_audio_features['Song'].duplicated().value_counts()
# Out:
# False    23551
# True      4941
# Name: Song, dtype: int64

# %%
df_hot_audio_features = df_hot_audio_features.drop_duplicates(subset=['Song'])
df_hot_audio_features['Song'].duplicated().value_counts()
# Out:
# False    23551
# Name: Song, dtype: int64

# %%
df_hot_audio_features.head(3)
# Out:
#                                               SongID  \
# 0                      AdictoTainy, Anuel AA & Ozuna
# 1  The Ones That Didn't Make It Back HomeJustin M...
# 2                  ShallowLady Gaga & Bradley Cooper
#
#                     Performer                                    Song  \
# 0     Tainy, Anuel AA & Ozuna                                  Adicto
# 1                Justin Moore  The Ones That Didn't Make It Back Home
# 2  Lady Gaga & Bradley Cooper                                 Shallow
#
#                                        spotify_genre  \
# 0                                  ['pop reggaeton']
# 1  ['arkansas country', 'contemporary country', '...
# 2                               ['dance pop', 'pop']
#
#    spotify_track_popularity  danceability  energy   key  loudness  mode  \
# 0                      91.0         0.734   0.836  10.0    -4.803   0.0
# 1                       NaN           NaN     NaN   NaN       NaN   NaN
# 2                      88.0         0.572   0.385   7.0    -6.362   1.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence   tempo  \
# 0       0.0735         0.017          0.000016     0.179    0.623  80.002
# 1          NaN           NaN               NaN       NaN      NaN     NaN
# 2       0.0308         0.371          0.000000     0.231    0.323  95.799
#
#    time_signature
# 0             4.0
# 1             NaN
# 2             4.0

# %%
print(df_hot_audio_features.shape)
df_bb.shape
# Out:
# (23551, 17)
# (7205, 7)

# %%
df_hot_audio_features.head()
# Out:
#                                               SongID  \
# 0                      AdictoTainy, Anuel AA & Ozuna
# 1  The Ones That Didn't Make It Back HomeJustin M...
# 2                  ShallowLady Gaga & Bradley Cooper
# 3                EnemiesPost Malone Featuring DaBaby
# 4    Bacc At It AgainYella Beezy, Gucci Mane & Quavo
#
#                          Performer                                    Song  \
# 0          Tainy, Anuel AA & Ozuna                                  Adicto
# 1                     Justin Moore  The Ones That Didn't Make It Back Home
# 2       Lady Gaga & Bradley Cooper                                 Shallow
# 3     Post Malone Featuring DaBaby                                 Enemies
# 4  Yella Beezy, Gucci Mane & Quavo                        Bacc At It Again
#
#                                        spotify_genre  \
# 0                                  ['pop reggaeton']
# 1  ['arkansas country', 'contemporary country', '...
# 2                               ['dance pop', 'pop']
# 3                  ['dfw rap', 'melodic rap', 'rap']
# 4     ['dfw rap', 'rap', 'southern hip hop', 'trap']
#
#    spotify_track_popularity  danceability  energy   key  loudness  mode  \
# 0                      91.0         0.734   0.836  10.0    -4.803   0.0
# 1                       NaN           NaN     NaN   NaN       NaN   NaN
# 2                      88.0         0.572   0.385   7.0    -6.362   1.0
# 3                      86.0         0.542   0.674   6.0    -4.169   1.0
# 4                      61.0         0.948   0.623   8.0    -5.725   0.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0735       0.01700          0.000016    0.1790    0.623   80.002
# 1          NaN           NaN               NaN       NaN      NaN      NaN
# 2       0.0308       0.37100          0.000000    0.2310    0.323   95.799
# 3       0.2100       0.05880          0.000000    0.0955    0.667   76.388
# 4       0.1680       0.00124          0.000001    0.0716    0.856  135.979
#
#    time_signature
# 0             4.0
# 1             NaN
# 2             4.0
# 3             4.0
# 4             4.0

# %%
df_bb.head()
# Out:
#                         Artists           Name  Weekly.rank  Peak.position  \
# 1                      Lil Nas,  Old Town Road            1            1.0
# 2  Shawn Mendes, Camila Cabello       Senorita            2            NaN
# 3                 Billie Eilish        Bad Guy            3            2.0
# 4                        Khalid           Talk            4            3.0
# 5     Ed Sheeran, Justin Bieber   I Don't Care            5            2.0
#
#    Weeks.on.chart                                              Genre  \
# 1             7.0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 2             NaN                                                Pop
# 3            13.0  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 4            20.0                                      Synth-Pop,Pop
# 5             7.0                      Canada,UK,Dance,Dance-Pop,Pop
#
#                                               Lyrics
# 1  Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...
# 2  Senorita \nI love it when you call me senorita...
# 3  bad guy \nWhite shirt now red, my bloody nose\...
# 4  Talk \nCan we just talk? Can we just talk?\nTa...
# 5  I Don't Care \nI'm at a party I don't wanna be...

# %% [markdown]
# ## Merging Data Frames on Song Title

# %%
## Show all columns
pd.set_option('display.max_columns', 100)

# %%
# Join Columns on both Artists and Song name

print(df_bb.shape, df_hot_audio_features.shape)
master_df = pd.merge(df_hot_audio_features, df_bb,
                  left_on=['Performer','Song'], right_on=['Artists','Name'],
                     how='inner')



# print(df_bb.shape)
# print(df_hot_audio_features.shape)
# print()
print(master_df.shape)
master_df.head(3)
# Out:
# (7205, 7) (23551, 17)
# (4119, 24)
#                                               SongID      Performer  \
# 0  The Ones That Didn't Make It Back HomeJustin M...   Justin Moore
# 1  Break Up With Your Girlfriend, I'm BoredAriana...  Ariana Grande
# 2                                    TrampolineSHAED          SHAED
#
#                                        Song  \
# 0    The Ones That Didn't Make It Back Home
# 1  Break Up With Your Girlfriend, I'm Bored
# 2                                Trampoline
#
#                                        spotify_genre  \
# 0  ['arkansas country', 'contemporary country', '...
# 1              ['dance pop', 'pop', 'post-teen pop']
# 2                              ['electropop', 'pop']
#
#    spotify_track_popularity  danceability  energy  key  loudness  mode  \
# 0                       NaN           NaN     NaN  NaN       NaN   NaN
# 1                      85.0         0.726   0.554  5.0    -5.290   0.0
# 2                      91.0         0.619   0.459  7.0    -5.782   0.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          NaN           NaN               NaN       NaN      NaN      NaN
# 1       0.0917        0.0421               0.0     0.106    0.335  169.999
# 2       0.0334        0.5600               0.0     0.137    0.498  126.803
#
#    time_signature        Artists                                      Name  \
# 0             NaN   Justin Moore    The Ones That Didn't Make It Back Home
# 1             4.0  Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2             4.0          SHAED                                Trampoline
#
#    Weekly.rank  Peak.position  Weeks.on.chart                         Genre  \
# 0           93           93.0             2.0                       Country
# 1           49            2.0            20.0  Trap,Trip-Hop,Lo-Fi,R&;B,Pop
# 2           77           77.0             4.0                           Pop
#
#                                               Lyrics
# 0  The Ones That Didn't Make It Back Home \nTour ...
# 1  break up with your girlfriend, i'm bored \nYou...
# 2  Trampoline \nI've been having dreams\nJumping ...

# %% [markdown]
# Next we need to deal with any remaining duplicates within our Song column.

# %%
## One duplicate
master_df['Song'].duplicated().value_counts()
# Out:
# False    4118
# True        1
# Name: Song, dtype: int64

# %%
## Remove last duplicate
master_df = master_df.drop_duplicates(subset=['Song'])
master_df['Song'].duplicated().value_counts()
# Out:
# False    4118
# Name: Song, dtype: int64

# %% [markdown]
# We will be dealing with the additional null values later on. For now we can focus on merging the rest of the data.

# %%
master_df.isna().sum()
# Out:
# SongID                        0
# Performer                     0
# Song                          0
# spotify_genre                20
# spotify_track_popularity    114
# danceability                119
# energy                      119
# key                         119
# loudness                    119
# mode                        119
# speechiness                 119
# acousticness                119
# instrumentalness            119
# liveness                    119
# valence                     119
# tempo                       119
# time_signature              119
# Artists                       0
# Name                          0
# Weekly.rank                   0
# Peak.position               656
# Weeks.on.chart              656
# Genre                         0
# Lyrics                        0
# dtype: int64

# %%
master_df.head(3)
# Out:
#                                               SongID      Performer  \
# 0  The Ones That Didn't Make It Back HomeJustin M...   Justin Moore
# 1  Break Up With Your Girlfriend, I'm BoredAriana...  Ariana Grande
# 2                                    TrampolineSHAED          SHAED
#
#                                        Song  \
# 0    The Ones That Didn't Make It Back Home
# 1  Break Up With Your Girlfriend, I'm Bored
# 2                                Trampoline
#
#                                        spotify_genre  \
# 0  ['arkansas country', 'contemporary country', '...
# 1              ['dance pop', 'pop', 'post-teen pop']
# 2                              ['electropop', 'pop']
#
#    spotify_track_popularity  danceability  energy  key  loudness  mode  \
# 0                       NaN           NaN     NaN  NaN       NaN   NaN
# 1                      85.0         0.726   0.554  5.0    -5.290   0.0
# 2                      91.0         0.619   0.459  7.0    -5.782   0.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          NaN           NaN               NaN       NaN      NaN      NaN
# 1       0.0917        0.0421               0.0     0.106    0.335  169.999
# 2       0.0334        0.5600               0.0     0.137    0.498  126.803
#
#    time_signature        Artists                                      Name  \
# 0             NaN   Justin Moore    The Ones That Didn't Make It Back Home
# 1             4.0  Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2             4.0          SHAED                                Trampoline
#
#    Weekly.rank  Peak.position  Weeks.on.chart                         Genre  \
# 0           93           93.0             2.0                       Country
# 1           49            2.0            20.0  Trap,Trip-Hop,Lo-Fi,R&;B,Pop
# 2           77           77.0             4.0                           Pop
#
#                                               Lyrics
# 0  The Ones That Didn't Make It Back Home \nTour ...
# 1  break up with your girlfriend, i'm bored \nYou...
# 2  Trampoline \nI've been having dreams\nJumping ...

# %% [markdown]
# ## Merging our master_df with our control data set

# %%
master_df.head(1)
# Out:
#                                               SongID     Performer  \
# 0  The Ones That Didn't Make It Back HomeJustin M...  Justin Moore
#
#                                      Song  \
# 0  The Ones That Didn't Make It Back Home
#
#                                        spotify_genre  \
# 0  ['arkansas country', 'contemporary country', '...
#
#    spotify_track_popularity  danceability  energy  key  loudness  mode  \
# 0                       NaN           NaN     NaN  NaN       NaN   NaN
#
#    speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# 0          NaN           NaN               NaN       NaN      NaN    NaN
#
#    time_signature       Artists                                    Name  \
# 0             NaN  Justin Moore  The Ones That Didn't Make It Back Home
#
#    Weekly.rank  Peak.position  Weeks.on.chart    Genre  \
# 0           93           93.0             2.0  Country
#
#                                               Lyrics
# 0  The Ones That Didn't Make It Back Home \nTour ...

# %%
df_rando.head(1)
# Out:
#      Title       Artist        Top Genre  Year  Beats Per Minute (BPM)  \
# 0  Sunrise  Norah Jones  adult standards  2004                     157
#
#    Energy  Danceability  Loudness (dB)  Liveness  Valence Length (Duration)  \
# 0      30            53            -14        11       68               201
#
#    Acousticness  Speechiness  Popularity  \
# 0            94            3          71
#
#                                               Lyrics
# 0  \nSunrise, sunrise\nLooks like mornin' in your...

# %% [markdown]
# Dropping columns in df_rando that are not in master df and vice versa aside from the billboard rankings which we will fill out later.

# %%
# title, yes
# artist, yes
# year, no
# bpm, no
# energy, yes
# dance, yes
# loudness, yes
# liveness, yes
# valence, yes
# length, yes
# accousticness, yes
# speechiness, yes
# pupularity, yes
df_rando = df_rando.drop(['Beats Per Minute (BPM)','Year'], axis=1)
df_rando.head(3)
# Out:
#             Title       Artist            Top Genre  Energy  Danceability  \
# 0         Sunrise  Norah Jones      adult standards      30            53
# 1     Black Night  Deep Purple           album rock      79            50
# 2  Clint Eastwood     Gorillaz  alternative hip hop      69            66
#
#    Loudness (dB)  Liveness  Valence Length (Duration)  Acousticness  \
# 0            -14        11       68               201            94
# 1            -11        17       81               207            17
# 2             -9         7       52               341             2
#
#    Speechiness  Popularity                                             Lyrics
# 0            3          71  \nSunrise, sunrise\nLooks like mornin' in your...
# 1            7          39  \nBlack night is not right\nI don't feel so br...
# 2           17          69  [Intro: 2D]\nHoo-hoo-hoo-hoo-hoo\n\n[Chorus: 2...

# %%
master_df.head(1)
# Out:
#                                               SongID     Performer  \
# 0  The Ones That Didn't Make It Back HomeJustin M...  Justin Moore
#
#                                      Song  \
# 0  The Ones That Didn't Make It Back Home
#
#                                        spotify_genre  \
# 0  ['arkansas country', 'contemporary country', '...
#
#    spotify_track_popularity  danceability  energy  key  loudness  mode  \
# 0                       NaN           NaN     NaN  NaN       NaN   NaN
#
#    speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# 0          NaN           NaN               NaN       NaN      NaN    NaN
#
#    time_signature       Artists                                    Name  \
# 0             NaN  Justin Moore  The Ones That Didn't Make It Back Home
#
#    Weekly.rank  Peak.position  Weeks.on.chart    Genre  \
# 0           93           93.0             2.0  Country
#
#                                               Lyrics
# 0  The Ones That Didn't Make It Back Home \nTour ...

# %%
# tempo, no
# instrumental, no
# mode, no
# key, no
# songid, no

master_df = master_df.drop(['SongID','tempo','instrumentalness','mode','key','Artists','Name'],axis=1)
master_df.head(3)
# Out:
#        Performer                                      Song  \
# 0   Justin Moore    The Ones That Didn't Make It Back Home
# 1  Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2          SHAED                                Trampoline
#
#                                        spotify_genre  \
# 0  ['arkansas country', 'contemporary country', '...
# 1              ['dance pop', 'pop', 'post-teen pop']
# 2                              ['electropop', 'pop']
#
#    spotify_track_popularity  danceability  energy  loudness  speechiness  \
# 0                       NaN           NaN     NaN       NaN          NaN
# 1                      85.0         0.726   0.554    -5.290       0.0917
# 2                      91.0         0.619   0.459    -5.782       0.0334
#
#    acousticness  liveness  valence  time_signature  Weekly.rank  \
# 0           NaN       NaN      NaN             NaN           93
# 1        0.0421     0.106    0.335             4.0           49
# 2        0.5600     0.137    0.498             4.0           77
#
#    Peak.position  Weeks.on.chart                         Genre  \
# 0           93.0             2.0                       Country
# 1            2.0            20.0  Trap,Trip-Hop,Lo-Fi,R&;B,Pop
# 2           77.0             4.0                           Pop
#
#                                               Lyrics
# 0  The Ones That Didn't Make It Back Home \nTour ...
# 1  break up with your girlfriend, i'm bored \nYou...
# 2  Trampoline \nI've been having dreams\nJumping ...

# %% [markdown]
# Next I'm going to deal with any null values by replacing them with the mean value of that column.

# %%
master_df = master_df.fillna(master_df.mean())

master_df.isna().sum()
# Out:
# Performer                    0
# Song                         0
# spotify_genre               20
# spotify_track_popularity     0
# danceability                 0
# energy                       0
# loudness                     0
# speechiness                  0
# acousticness                 0
# liveness                     0
# valence                      0
# time_signature               0
# Weekly.rank                  0
# Peak.position                0
# Weeks.on.chart               0
# Genre                        0
# Lyrics                       0
# dtype: int64

# %% [markdown]
# As there are only 20 songs that don't contain a genre we will be filling it with 'no genre'.

# %%
## Fill no genres with 'no genre'
master_df["spotify_genre"].fillna("['No Genre']", inplace = True)

# %% [markdown]
# Below I'm reviewing my data set before continuing.

# %%
master_df.isna().sum()
# Out:
# Performer                   0
# Song                        0
# spotify_genre               0
# spotify_track_popularity    0
# danceability                0
# energy                      0
# loudness                    0
# speechiness                 0
# acousticness                0
# liveness                    0
# valence                     0
# time_signature              0
# Weekly.rank                 0
# Peak.position               0
# Weeks.on.chart              0
# Genre                       0
# Lyrics                      0
# dtype: int64

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4118 entries, 0 to 4118
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Performer                 4118 non-null   object
#  1   Song                      4118 non-null   object
#  2   spotify_genre             4118 non-null   object
#  3   spotify_track_popularity  4118 non-null   float64
#  4   danceability              4118 non-null   float64
#  5   energy                    4118 non-null   float64
#  6   loudness                  4118 non-null   float64
#  7   speechiness               4118 non-null   float64
#  8   acousticness              4118 non-null   float64
#  9   liveness                  4118 non-null   float64
#  10  valence                   4118 non-null   float64
#  11  time_signature            4118 non-null   float64
#  12  Weekly.rank               4118 non-null   int64
#  13  Peak.position             4118 non-null   float64
#  14  Weeks.on.chart            4118 non-null   float64
#  15  Genre                     4118 non-null   object
#  16  Lyrics                    4118 non-null   object
# dtypes: float64(11), int64(1), object(5)
# memory usage: 579.1+ KB

# %%
## Converting to float to make the features it align with it's other numerical
## features
master_df['Weekly.rank'] = master_df['Weekly.rank'].astype(float)

master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4118 entries, 0 to 4118
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Performer                 4118 non-null   object
#  1   Song                      4118 non-null   object
#  2   spotify_genre             4118 non-null   object
#  3   spotify_track_popularity  4118 non-null   float64
#  4   danceability              4118 non-null   float64
#  5   energy                    4118 non-null   float64
#  6   loudness                  4118 non-null   float64
#  7   speechiness               4118 non-null   float64
#  8   acousticness              4118 non-null   float64
#  9   liveness                  4118 non-null   float64
#  10  valence                   4118 non-null   float64
#  11  time_signature            4118 non-null   float64
#  12  Weekly.rank               4118 non-null   float64
#  13  Peak.position             4118 non-null   float64
#  14  Weeks.on.chart            4118 non-null   float64
#  15  Genre                     4118 non-null   object
#  16  Lyrics                    4118 non-null   object
# dtypes: float64(12), object(5)
# memory usage: 579.1+ KB

# %%
df_rando.dtypes
# Out:
# Title                object
# Artist               object
# Top Genre            object
# Energy                int64
# Danceability          int64
# Loudness (dB)         int64
# Liveness              int64
# Valence               int64
# Length (Duration)    object
# Acousticness          int64
# Speechiness           int64
# Popularity            int64
# Lyrics               object
# dtype: object

# %%
df_rando.head(10)
# Out:
#                                    Title             Artist  \
# 0                                Sunrise        Norah Jones
# 1                            Black Night        Deep Purple
# 2                         Clint Eastwood           Gorillaz
# 3                          The Pretender       Foo Fighters
# 4                 Waitin' On A Sunny Day  Bruce Springsteen
# 5  The Road Ahead (Miles Of The Unknown)       City To City
# 6                      She Will Be Loved           Maroon 5
# 7                     Knights of Cydonia               Muse
# 8                         Mr. Brightside        The Killers
# 9                             Without Me             Eminem
#
#               Top Genre  Energy  Danceability  Loudness (dB)  Liveness  \
# 0       adult standards      30            53            -14        11
# 1            album rock      79            50            -11        17
# 2   alternative hip hop      69            66             -9         7
# 3     alternative metal      96            43             -4         3
# 4          classic rock      82            58             -5        10
# 5  alternative pop rock      46            54             -9        14
# 6                   pop      71            71             -6        13
# 7           modern rock      96            37             -5        12
# 8           modern rock      92            36             -4        10
# 9       detroit hip hop      67            91             -3        24
#
#    Valence Length (Duration)  Acousticness  Speechiness  Popularity  \
# 0       68               201            94            3          71
# 1       81               207            17            7          39
# 2       52               341             2           17          69
# 3       37               269             0            4          76
# 4       87               256             1            3          59
# 5       14               247             0            2          45
# 6       54               257             6            3          74
# 7       21               366             0           14          69
# 8       23               223             0            8          77
# 9       66               290             0            7          82
#
#                                               Lyrics
# 0  \nSunrise, sunrise\nLooks like mornin' in your...
# 1  \nBlack night is not right\nI don't feel so br...
# 2  [Intro: 2D]\nHoo-hoo-hoo-hoo-hoo\n\n[Chorus: 2...
# 3  \nKeep you in the dark\nYou know they all pret...
# 4  \nIt's raining, but there ain't a cloud in the...
# 5  MASON CITY\nTo get there you follow Highway 58...
# 6  \nBeauty queen of only eighteen\nShe had some ...
# 7  [Instrumental Intro with Vocalizations]\n\n\nC...
# 8  \nComing out of my cage and I've been doing ju...
# 9  [Intro: Obie Trice]\nObie Trice! Real name, no...

# %% [markdown]
# First I'm going to rename the columns in my master data frame to map our random data frame. This way when we join we will eliminate duplicate columns appearing. It will also look much cleaner.

# %%
master_df.rename(columns={'Song':'Title', 'Performer':'Artist',
                         'spotify_genre':'Top Genre',
                          'spotify_track_popularity':'Popularity',
                         'danceability':'Danceability','loudness':'Loudness (dB)',
                        'energy':'Energy','speechiness':'Speechiness',
                        'acousticness':'Acousticness','liveness':'Liveness',
                          'valence':'Valence','time_signature':'Length (Duration)',
                        }, inplace=True)

# %%
master_df.head(5)
# Out:
#           Artist                                     Title  \
# 0   Justin Moore    The Ones That Didn't Make It Back Home
# 1  Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2          SHAED                                Trampoline
# 3  Blake Shelton                             God's Country
# 4         Halsey                                Without Me
#
#                                            Top Genre  Popularity  \
# 0  ['arkansas country', 'contemporary country', '...   57.768731
# 1              ['dance pop', 'pop', 'post-teen pop']   85.000000
# 2                              ['electropop', 'pop']   91.000000
# 3  ['contemporary country', 'country', 'country r...   77.000000
# 4  ['dance pop', 'electropop', 'etherpop', 'indie...   89.000000
#
#    Danceability    Energy  Loudness (dB)  Speechiness  Acousticness  Liveness  \
# 0      0.611624  0.692393      -5.903244     0.089802      0.173307  0.181164
# 1      0.726000  0.554000      -5.290000     0.091700      0.042100  0.106000
# 2      0.619000  0.459000      -5.782000     0.033400      0.560000  0.137000
# 3      0.538000  0.752000      -5.106000     0.039600      0.060800  0.118000
# 4      0.752000  0.488000      -7.050000     0.070500      0.297000  0.093600
#
#     Valence  Length (Duration)  Weekly.rank  Peak.position  Weeks.on.chart  \
# 0  0.508448           3.967992         93.0           93.0             2.0
# 1  0.335000           4.000000         49.0            2.0            20.0
# 2  0.498000           4.000000         77.0           77.0             4.0
# 3  0.217000           4.000000         18.0           18.0            13.0
# 4  0.533000           4.000000         17.0            1.0            38.0
#
#                                                Genre  \
# 0                                            Country
# 1                       Trap,Trip-Hop,Lo-Fi,R&;B,Pop
# 2                                                Pop
# 3                                            Country
# 4  Synth-Pop,R&;B,Alternative Pop,Ballad,Pop,Alte...
#
#                                               Lyrics
# 0  The Ones That Didn't Make It Back Home \nTour ...
# 1  break up with your girlfriend, i'm bored \nYou...
# 2  Trampoline \nI've been having dreams\nJumping ...
# 3  God's Country \nRight outside of this one chur...
# 4  Without Me \nFound you when your heart was bro...

# %% [markdown]
# # Correcting our genre column to be more digestible

# %% [markdown]
# The next challenge is to fix our genres column and simplify our genres to one singular general genera. e.g. 'country, folk country' = 'country' instead.

# %%
master_df.loc[0,'Top Genre']
# Out:
# "['arkansas country', 'contemporary country', 'country', 'country road', 'modern country rock', 'redneck']"

# %% [markdown]
# Right now our top genre columns contents are a string. Python’s eval() allows me to evaluate  expressions from a string-based or compiled-code-based input. Which will basically help me convert this back into a list.

# %%
## Experimenting, it worked
eval(master_df.loc[0,'Top Genre'])
# Out:
# ['arkansas country',
#  'contemporary country',
#  'country',
#  'country road',
#  'modern country rock',
#  'redneck']

# %%
## applying to the entire column
master_df['Top Genre'] = master_df['Top Genre'].apply(eval)

print(master_df.loc[0,'Top Genre'])
# Out:
# ['arkansas country', 'contemporary country', 'country', 'country road', 'modern country rock', 'redneck']

# %% [markdown]
# Now my goal is to turn this back into a string, by leveraging our .join function. I'm doing this so that when I join our master_df and rando_df below they'll be in the same 'format'.

# %%
' '.join(master_df.loc[0,'Top Genre'])
# Out:
# 'arkansas country contemporary country country country road modern country rock redneck'

# %%
master_df['Top Genre'] = [', '.join(map(str, l)) for l in master_df['Top Genre']]

master_df.head()
# Out:
#           Artist                                     Title  \
# 0   Justin Moore    The Ones That Didn't Make It Back Home
# 1  Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2          SHAED                                Trampoline
# 3  Blake Shelton                             God's Country
# 4         Halsey                                Without Me
#
#                                            Top Genre  Popularity  \
# 0  arkansas country, contemporary country, countr...   57.768731
# 1                      dance pop, pop, post-teen pop   85.000000
# 2                                    electropop, pop   91.000000
# 3  contemporary country, country, country road, o...   77.000000
# 4  dance pop, electropop, etherpop, indie poptimi...   89.000000
#
#    Danceability    Energy  Loudness (dB)  Speechiness  Acousticness  Liveness  \
# 0      0.611624  0.692393      -5.903244     0.089802      0.173307  0.181164
# 1      0.726000  0.554000      -5.290000     0.091700      0.042100  0.106000
# 2      0.619000  0.459000      -5.782000     0.033400      0.560000  0.137000
# 3      0.538000  0.752000      -5.106000     0.039600      0.060800  0.118000
# 4      0.752000  0.488000      -7.050000     0.070500      0.297000  0.093600
#
#     Valence  Length (Duration)  Weekly.rank  Peak.position  Weeks.on.chart  \
# 0  0.508448           3.967992         93.0           93.0             2.0
# 1  0.335000           4.000000         49.0            2.0            20.0
# 2  0.498000           4.000000         77.0           77.0             4.0
# 3  0.217000           4.000000         18.0           18.0            13.0
# 4  0.533000           4.000000         17.0            1.0            38.0
#
#                                                Genre  \
# 0                                            Country
# 1                       Trap,Trip-Hop,Lo-Fi,R&;B,Pop
# 2                                                Pop
# 3                                            Country
# 4  Synth-Pop,R&;B,Alternative Pop,Ballad,Pop,Alte...
#
#                                               Lyrics
# 0  The Ones That Didn't Make It Back Home \nTour ...
# 1  break up with your girlfriend, i'm bored \nYou...
# 2  Trampoline \nI've been having dreams\nJumping ...
# 3  God's Country \nRight outside of this one chur...
# 4  Without Me \nFound you when your heart was bro...

# %% [markdown]
# Now I'm going to make sure none of df_rando songs are in our top 100 master_df and vice versa. This will make sure the data is truly clean on both sides.

# %%
master_df.Title.isin(df_rando.Title).value_counts()
# Out:
# False    3904
# True      214
# Name: Title, dtype: int64

# %%
df_rando.Title.isin(master_df.Title).value_counts()
# Out:
# False    1773
# True      221
# Name: Title, dtype: int64

# %%
master_df_cleaned = (master_df[~master_df.Title.isin(df_rando.Title)])
rando_df_cleanded = (df_rando[~df_rando.Title.isin(master_df.Title)])

# %%
master_df_cleaned.head()
# Out:
#                 Artist                                     Title  \
# 0         Justin Moore    The Ones That Didn't Make It Back Home
# 1        Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2                SHAED                                Trampoline
# 3        Blake Shelton                             God's Country
# 5  5 Seconds Of Summer                                    Easier
#
#                                            Top Genre  Popularity  \
# 0  arkansas country, contemporary country, countr...   57.768731
# 1                      dance pop, pop, post-teen pop   85.000000
# 2                                    electropop, pop   91.000000
# 3  contemporary country, country, country road, o...   77.000000
# 5            boy band, dance pop, pop, post-teen pop   81.000000
#
#    Danceability    Energy  Loudness (dB)  Speechiness  Acousticness  Liveness  \
# 0      0.611624  0.692393      -5.903244     0.089802      0.173307  0.181164
# 1      0.726000  0.554000      -5.290000     0.091700      0.042100  0.106000
# 2      0.619000  0.459000      -5.782000     0.033400      0.560000  0.137000
# 3      0.538000  0.752000      -5.106000     0.039600      0.060800  0.118000
# 5      0.505000  0.428000      -5.604000     0.221000      0.489000  0.097700
#
#     Valence  Length (Duration)  Weekly.rank  Peak.position  Weeks.on.chart  \
# 0  0.508448           3.967992         93.0           93.0             2.0
# 1  0.335000           4.000000         49.0            2.0            20.0
# 2  0.498000           4.000000         77.0           77.0             4.0
# 3  0.217000           4.000000         18.0           18.0            13.0
# 5  0.618000           4.000000         64.0           48.0             5.0
#
#                           Genre  \
# 0                       Country
# 1  Trap,Trip-Hop,Lo-Fi,R&;B,Pop
# 2                           Pop
# 3                       Country
# 5                 Australia,Pop
#
#                                               Lyrics
# 0  The Ones That Didn't Make It Back Home \nTour ...
# 1  break up with your girlfriend, i'm bored \nYou...
# 2  Trampoline \nI've been having dreams\nJumping ...
# 3  God's Country \nRight outside of this one chur...
# 5  Easier \nIs it easier to stay? Is it easier to...

# %%
rando_df_cleanded.head()
# Out:
#                                    Title             Artist  \
# 0                                Sunrise        Norah Jones
# 1                            Black Night        Deep Purple
# 4                 Waitin' On A Sunny Day  Bruce Springsteen
# 5  The Road Ahead (Miles Of The Unknown)       City To City
# 7                     Knights of Cydonia               Muse
#
#               Top Genre  Energy  Danceability  Loudness (dB)  Liveness  \
# 0       adult standards      30            53            -14        11
# 1            album rock      79            50            -11        17
# 4          classic rock      82            58             -5        10
# 5  alternative pop rock      46            54             -9        14
# 7           modern rock      96            37             -5        12
#
#    Valence Length (Duration)  Acousticness  Speechiness  Popularity  \
# 0       68               201            94            3          71
# 1       81               207            17            7          39
# 4       87               256             1            3          59
# 5       14               247             0            2          45
# 7       21               366             0           14          69
#
#                                               Lyrics
# 0  \nSunrise, sunrise\nLooks like mornin' in your...
# 1  \nBlack night is not right\nI don't feel so br...
# 4  \nIt's raining, but there ain't a cloud in the...
# 5  MASON CITY\nTo get there you follow Highway 58...
# 7  [Instrumental Intro with Vocalizations]\n\n\nC...

# %% [markdown]
# Now that my column names are the same (except for the ones with additional data) and we have fully cleaned our data, we can now join the two data frames.

# %%
potential_master = pd.concat([master_df_cleaned,rando_df_cleanded])

# %%
print(rando_df_cleanded.shape)
print(master_df_cleaned.shape)
potential_master.shape
# Out:
# (1773, 13)
# (3904, 17)
# (5677, 17)

# %%
final_df = potential_master

print(final_df.shape)
final_df.head(3)
# Out:
# (5677, 17)
#           Artist                                     Title  \
# 0   Justin Moore    The Ones That Didn't Make It Back Home
# 1  Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2          SHAED                                Trampoline
#
#                                            Top Genre  Popularity  \
# 0  arkansas country, contemporary country, countr...   57.768731
# 1                      dance pop, pop, post-teen pop   85.000000
# 2                                    electropop, pop   91.000000
#
#    Danceability    Energy  Loudness (dB)  Speechiness  Acousticness  Liveness  \
# 0      0.611624  0.692393      -5.903244     0.089802      0.173307  0.181164
# 1      0.726000  0.554000      -5.290000     0.091700      0.042100  0.106000
# 2      0.619000  0.459000      -5.782000     0.033400      0.560000  0.137000
#
#     Valence Length (Duration)  Weekly.rank  Peak.position  Weeks.on.chart  \
# 0  0.508448           3.96799         93.0           93.0             2.0
# 1  0.335000                 4         49.0            2.0            20.0
# 2  0.498000                 4         77.0           77.0             4.0
#
#                           Genre  \
# 0                       Country
# 1  Trap,Trip-Hop,Lo-Fi,R&;B,Pop
# 2                           Pop
#
#                                               Lyrics
# 0  The Ones That Didn't Make It Back Home \nTour ...
# 1  break up with your girlfriend, i'm bored \nYou...
# 2  Trampoline \nI've been having dreams\nJumping ...

# %% [markdown]
# Next we're building out a top_100 column. This will allow our data to be prepped for our modeling as well as help separate our top 100 from not top 100. Any data that contains a value great than or equal to 1 in the peak position column is in the top 100. Any data that is null or holds a 0 is not part of top 100.

# %%
final_df['top_100'] = (final_df['Peak.position']>=1)

final_df.head()
# Out:
#                 Artist                                     Title  \
# 0         Justin Moore    The Ones That Didn't Make It Back Home
# 1        Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2                SHAED                                Trampoline
# 3        Blake Shelton                             God's Country
# 5  5 Seconds Of Summer                                    Easier
#
#                                            Top Genre  Popularity  \
# 0  arkansas country, contemporary country, countr...   57.768731
# 1                      dance pop, pop, post-teen pop   85.000000
# 2                                    electropop, pop   91.000000
# 3  contemporary country, country, country road, o...   77.000000
# 5            boy band, dance pop, pop, post-teen pop   81.000000
#
#    Danceability    Energy  Loudness (dB)  Speechiness  Acousticness  Liveness  \
# 0      0.611624  0.692393      -5.903244     0.089802      0.173307  0.181164
# 1      0.726000  0.554000      -5.290000     0.091700      0.042100  0.106000
# 2      0.619000  0.459000      -5.782000     0.033400      0.560000  0.137000
# 3      0.538000  0.752000      -5.106000     0.039600      0.060800  0.118000
# 5      0.505000  0.428000      -5.604000     0.221000      0.489000  0.097700
#
#     Valence Length (Duration)  Weekly.rank  Peak.position  Weeks.on.chart  \
# 0  0.508448           3.96799         93.0           93.0             2.0
# 1  0.335000                 4         49.0            2.0            20.0
# 2  0.498000                 4         77.0           77.0             4.0
# 3  0.217000                 4         18.0           18.0            13.0
# 5  0.618000                 4         64.0           48.0             5.0
#
#                           Genre  \
# 0                       Country
# 1  Trap,Trip-Hop,Lo-Fi,R&;B,Pop
# 2                           Pop
# 3                       Country
# 5                 Australia,Pop
#
#                                               Lyrics  top_100
# 0  The Ones That Didn't Make It Back Home \nTour ...     True
# 1  break up with your girlfriend, i'm bored \nYou...     True
# 2  Trampoline \nI've been having dreams\nJumping ...     True
# 3  God's Country \nRight outside of this one chur...     True
# 5  Easier \nIs it easier to stay? Is it easier to...     True

# %%
## Checking for class imbalance
final_df['top_100'].value_counts(1)
# Out:
# True     0.687687
# False    0.312313
# Name: top_100, dtype: float64

# %%
final_df[~final_df['top_100']]['Lyrics']
# Out:
# 0       \nSunrise, sunrise\nLooks like mornin' in your...
# 1       \nBlack night is not right\nI don't feel so br...
# 4       \nIt's raining, but there ain't a cloud in the...
# 5       MASON CITY\nTo get there you follow Highway 58...
# 7       [Instrumental Intro with Vocalizations]\n\n\nC...
#                               ...
# 1989    \nWell, since my baby left me\nWell, I found a...
# 1990    \nYou ain't nothing but a hound dog\nCrying al...
# 1991    \nDeep down in Louisiana close to New Orleans\...
# 1992
# 1993    \nI found my thrill on Blueberry Hill\nOn Blue...
# Name: Lyrics, Length: 1773, dtype: object

# %%
final_df[final_df['top_100']]['Lyrics']
# Out:
# 0       The Ones That Didn't Make It Back Home \nTour ...
# 1       break up with your girlfriend, i'm bored \nYou...
# 2       Trampoline \nI've been having dreams\nJumping ...
# 3       God's Country \nRight outside of this one chur...
# 5       Easier \nIs it easier to stay? Is it easier to...
#                               ...
# 4113    Yuck \nMy name is Paul Rothenberg, Attorney of...
# 4114    Zack and Codeine \nMan, my life so sweet, I fe...
# 4115    Zero \nI thought we were great\nYou took your ...
# 4117    Zoom \nBought a drop top Porsche, about to cut...
# 4118    Tonight the Heartache's on Me \nYou could've h...
# Name: Lyrics, Length: 3904, dtype: object

# %%
final_df.isna().sum()
# Out:
# Artist                  0
# Title                   0
# Top Genre               0
# Popularity              0
# Danceability            0
# Energy                  0
# Loudness (dB)           0
# Speechiness             0
# Acousticness            0
# Liveness                0
# Valence                 0
# Length (Duration)       0
# Weekly.rank          1773
# Peak.position        1773
# Weeks.on.chart       1773
# Genre                1773
# Lyrics                  0
# top_100                 0
# dtype: int64

# %% [markdown]
# Dropping 'Genre' as my 'Top Genre' has the all the genres in it now. And we can see that all of the genres mapped over correctly into Top Genre as there are no null values.

# %%
final_df.drop(['Genre'], axis=1, inplace=True)

final_df['Top Genre']
# Out:
# 0       arkansas country, contemporary country, countr...
# 1                           dance pop, pop, post-teen pop
# 2                                         electropop, pop
# 3       contemporary country, country, country road, o...
# 5                 boy band, dance pop, pop, post-teen pop
#                               ...
# 1989                                      adult standards
# 1990                                      adult standards
# 1991                                           blues rock
# 1992                                                bebop
# 1993                                      adult standards
# Name: Top Genre, Length: 5677, dtype: object

# %%
genre_corpus = final_df['Top Genre'].to_list()

## Viewing the most popular genres and recognizing there are similarites
FreqDist(genre_corpus)
# Out:
# FreqDist({'album rock': 399, 'contemporary country, country, country road': 236, 'contemporary country, country, country road, modern country rock': 223, 'adult standards': 116, 'dance pop, pop, post-teen pop': 115, '': 93, 'dutch pop': 86, 'glee club, hollywood, post-teen pop': 73, 'canadian hip hop, canadian pop, hip hop, pop rap, rap, toronto rap': 71, 'dutch indie': 71, ...})

# %% [markdown]
# I'm importing re as this method takes a regular expression pattern and a string and searches for that pattern within the string. This helps set me up for when I need to make our genres just one singular generic genre.

# %%
import re
## Most frequent / common genres
rep = ['Country','Metal','Pop','Classical','Rock','Electronic',
       'Rap','R&;B','Adult Standards','Indie','Cabaret','Hip Hop','Soul']
final_df['Top Genre_'] = [re.findall(r'|'.join(rep), i,
                                 re.IGNORECASE) for i in final_df['Top Genre']]

# %%
final_df['Top Genre_']
# Out:
# 0       [country, country, country, country, country, ...
# 1                                         [pop, pop, pop]
# 2                                              [pop, pop]
# 3                    [country, country, country, country]
# 5                                         [pop, pop, pop]
#                               ...
# 1989                                    [adult standards]
# 1990                                    [adult standards]
# 1991                                               [rock]
# 1992                                                   []
# 1993                                    [adult standards]
# Name: Top Genre_, Length: 5677, dtype: object

# %% [markdown]
# Now I'm going through my Top Genre_ list and making sure that the genres don't repeat in their cell like we saw above. eq() will perform comparisons of my dataframe column objects with constant, series or another dataframes objects.

# %%
final_df['Top Genre'][final_df['Top Genre_'].str.len().eq(0)].value_counts()
# Out:
#                                                                     93
# british invasion                                                    36
# permanent wave                                                      29
# No Genre                                                            20
# disco                                                               16
#                                                                     ..
# deep norteno, duranguense, musica potosina, norteno, norteno-sax     1
# escape room                                                          1
# brostep, complextro, edm, electro                                    1
# bubble trance, disco house, eurodance, german techno, trance         1
# disco house, vocal house                                             1
# Name: Top Genre, Length: 96, dtype: int64

# %% [markdown]
# Now that this is somewhat cleaned up. I need to replace every genre that's not in 'rep' with 'unique genre'. This will make the information more digestible, rather than having a genre look like 'cyberpunk'.

# %%
def replace_genre(rep, genre):
    #if genre has nothing in it or whitespace
    if len(genre)==0:
        return "Unique Genre"
    else:
        return max(set(genre), key=genre.count)
final_df['Top Genre_']=final_df['Top Genre_'].apply(lambda x: replace_genre(rep,
                                                                            x))

# %%
final_df['Top Genre_'].value_counts()
# Out:
# pop                1920
# country            1060
# rock                951
# rap                 610
# Unique Genre        471
# metal               235
# adult standards     121
# hip hop             107
# indie                85
# soul                 64
# cabaret              51
# electronic            1
# classical             1
# Name: Top Genre_, dtype: int64

# %%
final_df.head()
# Out:
#                 Artist                                     Title  \
# 0         Justin Moore    The Ones That Didn't Make It Back Home
# 1        Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2                SHAED                                Trampoline
# 3        Blake Shelton                             God's Country
# 5  5 Seconds Of Summer                                    Easier
#
#                                            Top Genre  Popularity  \
# 0  arkansas country, contemporary country, countr...   57.768731
# 1                      dance pop, pop, post-teen pop   85.000000
# 2                                    electropop, pop   91.000000
# 3  contemporary country, country, country road, o...   77.000000
# 5            boy band, dance pop, pop, post-teen pop   81.000000
#
#    Danceability    Energy  Loudness (dB)  Speechiness  Acousticness  Liveness  \
# 0      0.611624  0.692393      -5.903244     0.089802      0.173307  0.181164
# 1      0.726000  0.554000      -5.290000     0.091700      0.042100  0.106000
# 2      0.619000  0.459000      -5.782000     0.033400      0.560000  0.137000
# 3      0.538000  0.752000      -5.106000     0.039600      0.060800  0.118000
# 5      0.505000  0.428000      -5.604000     0.221000      0.489000  0.097700
#
#     Valence Length (Duration)  Weekly.rank  Peak.position  Weeks.on.chart  \
# 0  0.508448           3.96799         93.0           93.0             2.0
# 1  0.335000                 4         49.0            2.0            20.0
# 2  0.498000                 4         77.0           77.0             4.0
# 3  0.217000                 4         18.0           18.0            13.0
# 5  0.618000                 4         64.0           48.0             5.0
#
#                                               Lyrics  top_100 Top Genre_
# 0  The Ones That Didn't Make It Back Home \nTour ...     True    country
# 1  break up with your girlfriend, i'm bored \nYou...     True        pop
# 2  Trampoline \nI've been having dreams\nJumping ...     True        pop
# 3  God's Country \nRight outside of this one chur...     True    country
# 5  Easier \nIs it easier to stay? Is it easier to...     True        pop

# %%
final_df['Top Genre_'].value_counts()
# Out:
# pop                1920
# country            1060
# rock                951
# rap                 610
# Unique Genre        471
# metal               235
# adult standards     121
# hip hop             107
# indie                85
# soul                 64
# cabaret              51
# electronic            1
# classical             1
# Name: Top Genre_, dtype: int64

# %%
final_df.isna().sum()
# Out:
# Artist                  0
# Title                   0
# Top Genre               0
# Popularity              0
# Danceability            0
# Energy                  0
# Loudness (dB)           0
# Speechiness             0
# Acousticness            0
# Liveness                0
# Valence                 0
# Length (Duration)       0
# Weekly.rank          1773
# Peak.position        1773
# Weeks.on.chart       1773
# Lyrics                  0
# top_100                 0
# Top Genre_              0
# dtype: int64

# %%
## filling null with 0's

final_df['Weekly.rank'].fillna(value=0, inplace=True)
final_df['Peak.position'].fillna(value=0, inplace=True)
final_df['Weeks.on.chart'].fillna(value=0, inplace=True)

final_df.isna().sum()
# Out:
# Artist               0
# Title                0
# Top Genre            0
# Popularity           0
# Danceability         0
# Energy               0
# Loudness (dB)        0
# Speechiness          0
# Acousticness         0
# Liveness             0
# Valence              0
# Length (Duration)    0
# Weekly.rank          0
# Peak.position        0
# Weeks.on.chart       0
# Lyrics               0
# top_100              0
# Top Genre_           0
# dtype: int64

# %%
final_df.head(1)
# Out:
#          Artist                                   Title  \
# 0  Justin Moore  The Ones That Didn't Make It Back Home
#
#                                            Top Genre  Popularity  \
# 0  arkansas country, contemporary country, countr...   57.768731
#
#    Danceability    Energy  Loudness (dB)  Speechiness  Acousticness  Liveness  \
# 0      0.611624  0.692393      -5.903244     0.089802      0.173307  0.181164
#
#     Valence Length (Duration)  Weekly.rank  Peak.position  Weeks.on.chart  \
# 0  0.508448           3.96799         93.0           93.0             2.0
#
#                                               Lyrics  top_100 Top Genre_
# 0  The Ones That Didn't Make It Back Home \nTour ...     True    country

# %% [markdown]
# # Visualizing our lyrics with a WordCloud

# %% [markdown]
# ## Building our Not Top 100 WorldCloud

# %% [markdown]
# Now it's time to start exploring our data set and looking at how lyrics play a role within it. We'll be looking at bigrams, wordcloud visuals and barplots!

# %%
final_df.head()
# Out:
#                 Artist                                     Title  \
# 0         Justin Moore    The Ones That Didn't Make It Back Home
# 1        Ariana Grande  Break Up With Your Girlfriend, I'm Bored
# 2                SHAED                                Trampoline
# 3        Blake Shelton                             God's Country
# 5  5 Seconds Of Summer                                    Easier
#
#                                            Top Genre  Popularity  \
# 0  arkansas country, contemporary country, countr...   57.768731
# 1                      dance pop, pop, post-teen pop   85.000000
# 2                                    electropop, pop   91.000000
# 3  contemporary country, country, country road, o...   77.000000
# 5            boy band, dance pop, pop, post-teen pop   81.000000
#
#    Danceability    Energy  Loudness (dB)  Speechiness  Acousticness  Liveness  \
# 0      0.611624  0.692393      -5.903244     0.089802      0.173307  0.181164
# 1      0.726000  0.554000      -5.290000     0.091700      0.042100  0.106000
# 2      0.619000  0.459000      -5.782000     0.033400      0.560000  0.137000
# 3      0.538000  0.752000      -5.106000     0.039600      0.060800  0.118000
# 5      0.505000  0.428000      -5.604000     0.221000      0.489000  0.097700
#
#     Valence Length (Duration)  Weekly.rank  Peak.position  Weeks.on.chart  \
# 0  0.508448           3.96799         93.0           93.0             2.0
# 1  0.335000                 4         49.0            2.0            20.0
# 2  0.498000                 4         77.0           77.0             4.0
# 3  0.217000                 4         18.0           18.0            13.0
# 5  0.618000                 4         64.0           48.0             5.0
#
#                                               Lyrics  top_100 Top Genre_
# 0  The Ones That Didn't Make It Back Home \nTour ...     True    country
# 1  break up with your girlfriend, i'm bored \nYou...     True        pop
# 2  Trampoline \nI've been having dreams\nJumping ...     True        pop
# 3  God's Country \nRight outside of this one chur...     True    country
# 5  Easier \nIs it easier to stay? Is it easier to...     True        pop

# %%
corpus_not100 = final_df[~final_df['top_100']]['Lyrics'].to_list()

stopwords_ls = stopwords.words('english')
stopwords_ls[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
stopwords_ls.extend(string.punctuation)
stopwords_ls[-5:]
# Out:
# ['`', '{', '|', '}', '~']

# %% [markdown]
# Now the normal, word_tokenize function doesn't know how to effectively read words from my experience. For example the word can't would be produced as "can" "'t". Which is not what we want, we want the full words. I found that the tweet tokenizer is able to handle this dataset more appropriately.

# %%
from nltk.tokenize import TweetTokenizer

tknzr = TweetTokenizer()
token = tknzr.tokenize('.'.join(corpus_not100))

# %%
removed_tokens_not100 = [w.lower() for w in token if w.lower() not in stopwords_ls]
removed_tokens_not100[:25]
# Out:
# ['sunrise',
#  'sunrise',
#  'looks',
#  'like',
#  'mornin',
#  'eyes',
#  "clock's",
#  'held',
#  '9:15',
#  'hours',
#  'sunrise',
#  'sunrise',
#  'tempt',
#  'us',
#  'tried',
#  'cause',
#  "afternoon's",
#  'already',
#  'come',
#  'gone',
#  'said',
#  'hoo-ooh-ooh-ooh',
#  'hoo-ooh-ooh-ooh',
#  'hoo-ooh-ooh-ooh',
#  'surprise']

# %%
freq = FreqDist(removed_tokens_not100)
freq.most_common(50)
# Out:
# [('—', 54478),
#  ('2018', 39925),
#  ('scp', 36280),
#  ('’', 22137),
#  ('one', 13481),
#  ('”', 11952),
#  ('“', 11902),
#  ('like', 10768),
#  ('would', 9700),
#  ('know', 7780),
#  ('said', 7624),
#  ('feat', 7609),
#  ('time', 7285),
#  ('see', 6806),
#  ('de', 6440),
#  ('love', 6381),
#  ('tony', 6216),
#  ('us', 6160),
#  ('day', 5889),
#  ('man', 5881),
#  ('go', 5643),
#  ('people', 5363),
#  ('say', 5267),
#  ('never', 5148),
#  ("i'm", 5099),
#  ('get', 5025),
#  ('2017', 4883),
#  ('–', 4855),
#  ('could', 4725),
#  ('back', 4686),
#  ('...', 4621),
#  ('make', 4570),
#  ('come', 4492),
#  ('even', 4408),
#  ('way', 4365),
#  ('little', 4349),
#  ('life', 4314),
#  ('may', 4193),
#  ('made', 4057),
#  ('good', 3998),
#  ('take', 3905),
#  ('fn', 3865),
#  ('night', 3847),
#  ('two', 3769),
#  ('king', 3695),
#  ('want', 3678),
#  ('first', 3600),
#  ('oh', 3598),
#  ('got', 3592),
#  ('well', 3534)]

# %%
## Extending our stopword list to  pull out some words 
## we found non instrumental to our data.
stopwords_ls.extend(['—','2018','scp','’','”','“','feat','instrumental',
                     'l','Instrumental','outro'])

# %%
removed_tokens_not100 = [w.lower() for w in token if w.lower() not in stopwords_ls]
removed_tokens_not100[:25]
# Out:
# ['sunrise',
#  'sunrise',
#  'looks',
#  'like',
#  'mornin',
#  'eyes',
#  "clock's",
#  'held',
#  '9:15',
#  'hours',
#  'sunrise',
#  'sunrise',
#  'tempt',
#  'us',
#  'tried',
#  'cause',
#  "afternoon's",
#  'already',
#  'come',
#  'gone',
#  'said',
#  'hoo-ooh-ooh-ooh',
#  'hoo-ooh-ooh-ooh',
#  'hoo-ooh-ooh-ooh',
#  'surprise']

# %%
freq = FreqDist(removed_tokens_not100)
freq.most_common(50)
# Out:
# [('one', 13481),
#  ('like', 10768),
#  ('would', 9700),
#  ('know', 7780),
#  ('said', 7624),
#  ('time', 7285),
#  ('see', 6806),
#  ('de', 6440),
#  ('love', 6381),
#  ('tony', 6216),
#  ('us', 6160),
#  ('day', 5889),
#  ('man', 5881),
#  ('go', 5643),
#  ('people', 5363),
#  ('say', 5267),
#  ('never', 5148),
#  ("i'm", 5099),
#  ('get', 5025),
#  ('2017', 4883),
#  ('–', 4855),
#  ('could', 4725),
#  ('back', 4686),
#  ('...', 4621),
#  ('make', 4570),
#  ('come', 4492),
#  ('even', 4408),
#  ('way', 4365),
#  ('little', 4349),
#  ('life', 4314),
#  ('may', 4193),
#  ('made', 4057),
#  ('good', 3998),
#  ('take', 3905),
#  ('fn', 3865),
#  ('night', 3847),
#  ('two', 3769),
#  ('king', 3695),
#  ('want', 3678),
#  ('first', 3600),
#  ('oh', 3598),
#  ('got', 3592),
#  ('well', 3534),
#  ('thou', 3513),
#  ('right', 3485),
#  ('world', 3461),
#  ('new', 3390),
#  ('mit', 3332),
#  ('upon', 3314),
#  ('still', 3207)]

# %% [markdown]
# Next we're going to visualize the most common lyrics in a wordcloud not from our top 100 lyrics, which will show us how frequently a word appears based on how large it is. E.g. the bigger the word the more frequently it pops up.

# %%
# freq.plot(50)

# %%
wordcloud = WordCloud(stopwords=stopwords_ls, collocations=False)
wordcloud.generate(','.join(removed_tokens_not100))

plt.figure(figsize = (15,15), facecolor = 'black')
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## Building our Top 100 WordCloud

# %%
corpus_100 = final_df[final_df['top_100']]['Lyrics'].to_list()

stopwords_ls = stopwords.words('english')
stopwords_ls[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
stopwords_ls.extend(string.punctuation)
stopwords_ls[-5:]
# Out:
# ['`', '{', '|', '}', '~']

# %% [markdown]
# Now the normal, word_tokenize function doesn't know how to effectively read words from my experience. For example the word can't would be produced as "can" "'t". Which is not what we want, we want the full words. I found that the tweet tokenizer is able to handle this dataset more appropriately.

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()
token = tknzr.tokenize('.'.join(corpus_100))

# %%
removed_tokens_top100 = [w.lower() for w in token if w.lower() not in stopwords_ls]
removed_tokens_top100[:25]
# Out:
# ['ones',
#  'make',
#  'back',
#  'home',
#  'tour',
#  'middle',
#  'june',
#  'planning',
#  'welcome',
#  'home',
#  'barbecue',
#  'green',
#  'bean',
#  'casserole',
#  "grandma's",
#  'recipe',
#  'knock',
#  'door',
#  'around',
#  'two',
#  "o'clock",
#  'two',
#  'uniforms',
#  'heart',
#  'stopped']

# %%
freq = FreqDist(removed_tokens_top100)
freq.most_common(50)
# Out:
# [("i'm", 16913),
#  ('like', 11639),
#  ('know', 9950),
#  ('yeah', 9898),
#  ('love', 8768),
#  ('oh', 8441),
#  ('got', 7925),
#  ('get', 7457),
#  ('baby', 6173),
#  ('go', 5836),
#  ('cause', 5068),
#  ("ain't", 5038),
#  ('wanna', 4803),
#  ('one', 4730),
#  ("can't", 4611),
#  ('back', 4433),
#  ('time', 4397),
#  ('never', 4390),
#  ('see', 4318),
#  ('want', 4289),
#  ('say', 4288),
#  ('girl', 4282),
#  ('make', 4223),
#  ('let', 4107),
#  ('way', 3920),
#  ('take', 3810),
#  ('right', 3798),
#  ('come', 3442),
#  ("i'll", 3361),
#  ('need', 3174),
#  ('gonna', 3173),
#  ("that's", 3094),
#  ('feel', 3017),
#  ('tell', 2843),
#  ('could', 2689),
#  ('night', 2675),
#  ('hey', 2620),
#  ('little', 2597),
#  ('life', 2574),
#  ('think', 2533),
#  ('man', 2517),
#  ('good', 2504),
#  ('keep', 2338),
#  ("i've", 2314),
#  ('said', 2232),
#  ('give', 2205),
#  ('heart', 2174),
#  ('every', 2153),
#  ('look', 2036),
#  ('la', 2024)]

# %% [markdown]
# Next we're going to visualize the most common lyrics in a wordcloud from our top 100 lyrics, which will show us how frequently a word appears based on how large it is. E.g. the bigger the word the more frequently it pops up.

# %%
wordcloud = WordCloud(stopwords=stopwords_ls, collocations=False)
wordcloud.generate(','.join(removed_tokens_top100))

plt.figure(figsize = (15,15), facecolor = 'black')
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## Bigram

# %% [markdown]
# ### Bigram containing most fequent words not in the Billboards top 100
# Next I want to see the most common word duos in lyrics. I'll do this with a bigram.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
lyric = nltk.BigramCollocationFinder.from_words(removed_tokens_not100)
lyric_freq_not100 = lyric.score_ngrams(bigram_measures.raw_freq)

pd.DataFrame(lyric_freq_not100, columns=["Lyric","Freq"]).head(20)
# Out:
#                  Lyric      Freq
# 0      (zau, al-makan)  0.000510
# 1            (mme, de)  0.000473
# 2     (de, guermantes)  0.000403
# 3      (aaron, swartz)  0.000348
# 4        (de, charlus)  0.000322
# 5     (united, states)  0.000306
# 6             (oh, oh)  0.000219
# 7       (high, school)  0.000212
# 8         (yeah, yeah)  0.000205
# 9      (wazir, dandan)  0.000204
# 10     (mme, verdurin)  0.000202
# 11         (new, york)  0.000199
# 12              (🇮, 🇪)  0.000196
# 13      (chris, brown)  0.000188
# 14            (na, na)  0.000185
# 15         (omar, bin)  0.000185
# 16            (la, la)  0.000179
# 17         (..., tony)  0.000168
# 18  (auspicious, king)  0.000160
# 19          (one, day)  0.000160

# %% [markdown]
# ### Bigram containing most fequent words in the Billboards top 100

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
lyric = nltk.BigramCollocationFinder.from_words(removed_tokens_top100)
lyric_freq_top100 = lyric.score_ngrams(bigram_measures.raw_freq)

pd.DataFrame(lyric_freq_top100, columns=["Lyric","Freq"]).head(20)
# Out:
#             Lyric      Freq
# 0        (oh, oh)  0.003457
# 1    (yeah, yeah)  0.002740
# 2        (la, la)  0.001824
# 3        (na, na)  0.001404
# 4    (i'm, gonna)  0.001125
# 5    (love, love)  0.001045
# 6       (let, go)  0.001010
# 7      (hey, hey)  0.000905
# 8     (know, i'm)  0.000801
# 9    (cause, i'm)  0.000786
# 10   (feel, like)  0.000782
# 11     (oh, yeah)  0.000743
# 12   (know, know)  0.000616
# 13       (da, da)  0.000566
# 14    (like, i'm)  0.000563
# 15  (every, time)  0.000554
# 16   (baby, baby)  0.000539
# 17     (ooh, ooh)  0.000512
# 18    (yeah, i'm)  0.000501
# 19       (go, go)  0.000470

# %% [markdown]
# ## Exploring genre

# %% [markdown]
# Next I want to view some of my data when comparing genres to weekly ranks, peak positions and weeks on chart. I'm going to be combining both a bar plot and a swarm plot.

# %%
from numpy import median

sns.catplot(x="Top Genre_", y="Weekly.rank", kind="bar",
            estimator=np.median,data=final_df,
            height=10,aspect=11/10)
sns.swarmplot(x="Top Genre_", y="Weekly.rank", data=final_df,edgecolor='black',
              linewidth=0.5)
plt.show();

# %%
sns.catplot(x="Top Genre_", y="Peak.position", kind="bar",
            estimator=np.median,data=final_df,
            height=10,aspect=11/10)
sns.swarmplot(x="Top Genre_", y="Peak.position", data=final_df,
              edgecolor='black',
              linewidth=0.5)
plt.show();

# %%
sns.catplot(x="Top Genre_", y="Weeks.on.chart", kind="bar",
            estimator=np.median,data=final_df,
            height=10,aspect=11/10)
sns.swarmplot(x="Top Genre_", y="Weeks.on.chart", data=final_df,
             edgecolor='black',linewidth=0.5)
plt.show();

# %% [markdown]
# I was surprised to find out that country was always sitting in the number one seat. But my opinion may be biased. Following Country we found that Pop, Rap and Hip-Hop play a strong role in being in the top 100 as well. Throughout all of the three visuals above, Country, Pop and Rap / Hip Hop all remain undefeated.

# %% [markdown]
# # Train Test Split

# %%
## Exploring how many made it
final_df['top_100'].value_counts(1)
# Out:
# True     0.687687
# False    0.312313
# Name: top_100, dtype: float64

# %% [markdown]
# Label encoding below in order to prep our data for the target.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
final_df['top.100'] = le.fit_transform(final_df['top_100'])
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5677 entries, 0 to 1993
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Artist             5677 non-null   object
#  1   Title              5677 non-null   object
#  2   Top Genre          5677 non-null   object
#  3   Popularity         5677 non-null   float64
#  4   Danceability       5677 non-null   float64
#  5   Energy             5677 non-null   float64
#  6   Loudness (dB)      5677 non-null   float64
#  7   Speechiness        5677 non-null   float64
#  8   Acousticness       5677 non-null   float64
#  9   Liveness           5677 non-null   float64
#  10  Valence            5677 non-null   float64
#  11  Length (Duration)  5677 non-null   object
#  12  Weekly.rank        5677 non-null   float64
#  13  Peak.position      5677 non-null   float64
#  14  Weeks.on.chart     5677 non-null   float64
#  15  Lyrics             5677 non-null   object
#  16  top_100            5677 non-null   bool
#  17  Top Genre_         5677 non-null   object
#  18  top.100            5677 non-null   int64
# dtypes: bool(1), float64(11), int64(1), object(6)
# memory usage: 1008.2+ KB

# %%
y = final_df['top.100']
X = final_df['Lyrics']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.30,
                                                    random_state=10)

# %%
y_train.value_counts(1)
# Out:
# 1    0.687642
# 0    0.312358
# Name: top.100, dtype: float64

# %% [markdown]
# Leveraging tweet tokenizer again so it can capture the full word as stated earlier in the notebook.

# %%
tokenizer = nltk.TweetTokenizer(preserve_case=False)
tokenizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


## Initialize TfIdf Vectorizer, feed in function of tokenize
vectorizer = TfidfVectorizer(tokenizer=tokenizer.tokenize,
                            stop_words=stopwords_ls)

# Vectorize data and make X_train_tfidf and X_test_tfidf
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)
X_train_tfidf
# Out:
# <3973x81688 sparse matrix of type '<class 'numpy.float64'>'
# 	with 801923 stored elements in Compressed Sparse Row format>

# %%
X_train_resampled, y_train_resampled = SMOTE().fit_resample(X_train_tfidf, y_train)

# %% [markdown]
# # Random Forest

# %%
# fitting
rf = RandomForestClassifier(class_weight="balanced")
rf.fit(X_train_tfidf,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_hat_test = rf.predict(X_test_tfidf)
y_test_arr = y_test.to_numpy()

# %% [markdown]
# The below two functions will allow us to visualize our models using a confusion matrix as well show us the precision, accuracy, recall and f1-score.

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):    
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.2f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:0.2f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
#     plt.grid(False)
    plt.show()

# %%
## Evaluate and view my model.

from sklearn.metrics import multilabel_confusion_matrix

def evaluate_model(y_test,y_hat_test,X_test,clf=None,
                  scoring=None,
                   verbose=False,scorer=False,
                   classes=['Not Top 100','Top 100'],
                  normalize = 'true'):
    
    print(metrics.classification_report(y_test,y_hat_test,
                                        target_names=classes))
    if scoring is None:
        scoring = metrics.recall_score(y_test,y_hat_test,average='macro')
    
    cm = metrics.confusion_matrix(y_test, y_hat_test,
    normalize = normalize)
    plot_confusion_matrix(cm,
                      normalize    = False,
                      target_names = classes,
                      title        = "Confusion Matrix")


    if verbose:
        print("MODEL PARAMETERS:")

        print(pd.Series(rf.get_params()))
## Use scoring = recall_macro in gridsearch.        
    if scorer:
        
        return recall_macro(y_test,y_hat_test)

# %% [markdown]
# Now we're running our Random Forest model

# %%
evaluate_model(y_test_arr,y_hat_test,X_test_tfidf,rf)
# Out:
#               precision    recall  f1-score   support
#
#  Not Top 100       0.92      0.47      0.62       532
#      Top 100       0.80      0.98      0.88      1172
#
#     accuracy                           0.82      1704
#    macro avg       0.86      0.73      0.75      1704
# weighted avg       0.84      0.82      0.80      1704

# %%
## Grabbing most import lyrics
pd.Series(rf.feature_importances_,
          index=vectorizer.get_feature_names()).sort_values().tail(25).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # XGB

# %% [markdown]
# Next we're running our XGB model

# %%
## Fitting
xgb_rf = XGBClassifier()
xgb_rf.fit(X_train_tfidf, y_train)

y_pred2 = xgb_rf.predict(X_test_tfidf)

evaluate_model(y_test_arr,y_pred2,X_test,xgb_rf)
# Out:
#               precision    recall  f1-score   support
#
#  Not Top 100       0.90      0.64      0.75       532
#      Top 100       0.85      0.97      0.91      1172
#
#     accuracy                           0.86      1704
#    macro avg       0.88      0.80      0.83      1704
# weighted avg       0.87      0.86      0.86      1704

# %%
## Grabbing most import lyrics
pd.Series(xgb_rf.feature_importances_,
          index=vectorizer.get_feature_names()).sort_values().tail(25).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # SVM

# %% [markdown]
# Finally we're running our SVM model

# %%
from sklearn.svm import SVC

clf = SVC(kernel='linear',class_weight='balanced')
clf.fit(X_train_tfidf,y_train)
y_pred = clf.predict(X_test_tfidf)

evaluate_model(y_test_arr,y_pred,X_test_tfidf,clf)
# Out:
#               precision    recall  f1-score   support
#
#  Not Top 100       0.76      0.73      0.75       532
#      Top 100       0.88      0.89      0.89      1172
#
#     accuracy                           0.84      1704
#    macro avg       0.82      0.81      0.82      1704
# weighted avg       0.84      0.84      0.84      1704

# %% [markdown]
# Next I want to see our most important words, we'll do this by pulling them out from the coefficient which in turn, are our words. This will help us understand how important each word is.

# %%
coef = clf.coef_.todense()
coef.shape
words = pd.DataFrame(coef, columns=vectorizer.get_feature_names()).T
words
## Make the absolut value in another column.
# Out:
#                  0
# #0023212  0.000000
# #1-217    0.000000
# #10063    0.000000
# #10125    0.000000
# #11       0.000000
# ...            ...
# （         0.006525
# ）         0.006525
# ２人        0.001631
# ￼        -0.299033
# 💜        -0.001702
#
# [81688 rows x 1 columns]

# %%
top_words = words.sort_values(by=0,axis=0, ascending=False)
top_words.head(30)
# Out:
#                 0
# girl     2.881748
# might    2.068768
# front    1.818364
# bout     1.802342
# wanna    1.789969
# i'm      1.698252
# keep     1.666101
# cause    1.587499
# em       1.536806
# that's   1.536058
# truth    1.512255
# tonight  1.504143
# even     1.492773
# here's   1.414876
# else     1.408737
# good     1.394643
# three    1.320400
# made     1.292781
# yea      1.288751
# let's    1.284280
# waiting  1.279412
# beer     1.264831
# making   1.257060
# truck    1.246915
# side     1.242812
# i'ma     1.238310
# like     1.225177
# lucky    1.218651
# til      1.211608
# sexy     1.205099

# %%
## SVM Gridsearch
parameters = {'C': [1, 10], 
          'gamma': [0.001, 0.01, 1,'auto'],
             'class_weight':['balanced','None']}
model = SVC()
grid = GridSearchCV(estimator=model, param_grid=parameters)
# clf = SVC(kernel='linear',class_weight='balanced')
# clf.fit(X_train_tfidf,y_train)
# y_pred = clf.predict(X_test_tfidf)

# %%
grid.fit(X_train_tfidf,y_train)
print(grid)
# summarization of results of the grid search
print(grid.best_score_)
print(grid.best_estimator_)

evaluate_model(y_test_arr,y_pred,X_test_tfidf,grid.best_estimator_)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10], 'class_weight': ['balanced', 'None'],
#                          'gamma': [0.001, 0.01, 1, 'auto']})
# 0.8240631782393105
# SVC(C=1, class_weight='balanced', gamma=1)
#               precision    recall  f1-score   support
#
#  Not Top 100       0.76      0.73      0.75       532
#      Top 100       0.88      0.89      0.89      1172
#
#     accuracy                           0.84      1704
#    macro avg       0.82      0.81      0.82      1704
# weighted avg       0.84      0.84      0.84      1704

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion the model that performed most strongly was our SVM model. We found that there are certain lyrics that appeared most frequently as well as had the most impact when it came to these lyrics being in the top 100. Some of the most important lyrics found were:
# - Girl
# - Wanna
# - Tonight
# - Truck
# - Sexy
# - Beer
# - Lucky
#
# There were also plenty of lyrics that would be considered by most as 'common' which in fairness they are. I believe this speaks to the simplicity of the music industry, lyrically at least.
#
# Some additional recommendations I'd add are to:
#
# - Leverage hooks, chorus and outro lyrics such as “oh, oh”, “la, la”, “hey, hey” etc.
#
# - Don’t sing about specific locations
#
# Another thing to take note on is how genre plays a role in regards to being in the top 100. The three most successful categories were Country, Pop and Hip Hop / Rap. My suggestion to anyone looking to make headway in music would be to leverage the important words we found and make sure it's in one of the 3 or a combination of the 2 genres stated previously.
